# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/ASP Grp 3 Panda 冠军队 Team/ASP AIML Model Training
# Out:
# /content/drive/MyDrive/ASP Grp 3 Panda 冠军队 Team/ASP AIML Model Training

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/ASP Grp 3 Panda 冠军队 Team/ASP AIML Model Training'

# %%
import nltk
from nltk.stem.porter import PorterStemmer
import json
import numpy as np

import torch 
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

import random

nltk.download("punkt")
stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
def tokenize(sentence):
  return nltk.word_tokenize(sentence)

# %%
def stem(word):
  return stemmer.stem(word.lower())

# %%
def bag_of_words(tokenized_sentence, all_words):
  """
  sentence = ["hello", "how", "are", "you"]
  words = ["hi", "hello", "I", "you", "bye", "thank", "cool"]
  bag = [0, 1, 0, 1, 0, 0, 0]
  """
  tokenized_sentence = [stem(w) for w in tokenized_sentence]

  bag = np.zeros(len(all_words), dtype = np.float32)
  for idx, w in enumerate(all_words):
    if w in tokenized_sentence:
      bag[idx] = 1.0
  
  return bag

# %%
sentence = ["hello", "how", "are", "you"]
words = ["hi", "hello", "I", "you", "bye", "thank", "cool"]
bag = bag_of_words(sentence, words)
print(bag)
# Out:
# [0. 1. 0. 1. 0. 0. 0.]

# %%
words = ["Organize", "organizes", "organizing"]
stemmed_words = [stem(x) for x in words]
print(stemmed_words)
# Out:
# ['organ', 'organ', 'organ']

# %%
with open("intents.json", "r") as f:
  intents = json.load(f)

print(intents)
# Out:
# {'intents': [{'tag': 'greeting', 'patterns': ['Hi', 'Hey', 'How are you?', 'Hi Chatbot', 'Hello', 'Good morning', 'Good afternoon', 'Good evening', 'Howdy chatbot', 'Are you the Question and Answer chatbot I am looking for?'], 'responses': ['Hi there, is there any question you have that I can answer?', 'Hello, I am here to answer to answer any questions you possibly have. Do not hesistate to ask me any as it is my duty to help you/']}, {'tag': 'farewell', 'patterns': ['Bye', 'See you later', 'Goodbye', 'See you next time', 'I will be back later', 'Hope to see you again', 'Good night'], 'responses': ['Thank you. Do not hesistate to come back to ask me anymore questions', 'Thank you. Please ask me more questions later if you have more to ask.']}, {'tag': 'about', 'patterns': ['What is Chronic Kidney Disease?', 'Is Chronic Kidney Disease the same as CKD?', 'Can you explain to me what is CKD', 'Is CKD a sudden disease like heart attack?', 'How does CKD affect the kidneys?'], 'responses': ['Chronic Kidney Disease also known as CKD is a condition in which the kidneys are damaged and are not able to filter waste and excess fluids from the body as effectively as they should. It is a progressive disease, which means that it gets worse over time.']}, {'tag': 'causes', 'patterns': ['What are the causes of CKD?', 'Is diabetes one of the causes of CKD?', 'Is high blood pressure one of the causes of CKD?'], 'responses': ['There are several causes of CKD, including diabetes, high blood pressure, and certain infections.', 'Possible causes include diabetes, high blood pressure, and certain infections.', 'The main causes of CKD are diabetes and high blood pressure.']}, {'tag': 'symptoms', 'patterns': ['Are there any symptops of CKD?', 'What are the symptoms of CKD?', 'Are there any complications associated with CKD?', 'What is the worst symptom of CKD?', 'How does CKD affect the body?', 'Is one of the symptops of CKD fatigue?', 'Is one of the symptops of CKD swelling?', 'Is one of the symptops of CKD changes in urine output?', 'Is one of the symptops of CKD anemia?', 'Is one of the symptops of CKD bone disease?', 'Is one of the symptops of CKD high blood pressure?', 'Is one of the symptops of CKD infections?', 'Is one of the symptops of CKD nerve damage?', 'Is one of the symptops of CKD poor nutrition?', 'Can you provide me a list of symptoms for CKD?', 'Can CKD cause kidney failure?'], 'responses': ['Symptoms of CKD may include swelling in the ankles and feet, fatigue, changes in urine output, anemia (low red blood cell count), bone disease, high blood pressure, infections, nerve damage and poor nutrition. Worst cases include kidney failure.']}, {'tag': 'diagnosis', 'patterns': ['How is CKD diagnosed?', 'Can you diagnose CKD?', 'How does the app and hardware help diagnose CKD?'], 'responses': ["CKD is diagnosed through blood, and urine tests, and imaging tests such as ultrasound or CT scan. To conduct the tests, one has to travel to a polyclinic or hospital which can be quite inconvenient. The app and hardware diagnose CKD by checking ammonia level based on user's breath. After checking, the user can see their CKD stage and advices on what to do next will be given by the chatbot. User can detect their CKD stages through the app."]}, {'tag': 'treatment', 'patterns': ['How is CKD treated?', 'How is CKD treated in children?', 'What is the treatment for advanced CKD?', 'Can CKD be managed with diet and exercise alone?', 'How is CKD treated in the early stages?', 'What are the possible treatments for advanced CKD?', 'Can CKD be treated?', 'Can CKD be treated with medications?', 'Can CKD be treated with a kidney transplant?', 'Can CKD be treated with dialysis?', 'Can CKD be treated with exercise?'], 'responses': ['In the early stages of CKD, treatment may focus on managing the underlying cause of the disease and slowing the progression of the kidney damage. Treatment for CKD may involve medications, lifestyle changes (such as eating healthily and ge ...

# %%
all_words = []
tags = []
xy = []
for intent in intents["intents"]:
  tag = intent["tag"]
  tags.append(tag)
  for pattern in intent["patterns"]:
    w = tokenize(pattern)
    all_words.extend(w)
    xy.append((w, tag))

# %%
print(all_words)
# Out:
# ['Hi', 'Hey', 'How', 'are', 'you', '?', 'Hi', 'Chatbot', 'Hello', 'Good', 'morning', 'Good', 'afternoon', 'Good', 'evening', 'Howdy', 'chatbot', 'Are', 'you', 'the', 'Question', 'and', 'Answer', 'chatbot', 'I', 'am', 'looking', 'for', '?', 'Bye', 'See', 'you', 'later', 'Goodbye', 'See', 'you', 'next', 'time', 'I', 'will', 'be', 'back', 'later', 'Hope', 'to', 'see', 'you', 'again', 'Good', 'night', 'What', 'is', 'Chronic', 'Kidney', 'Disease', '?', 'Is', 'Chronic', 'Kidney', 'Disease', 'the', 'same', 'as', 'CKD', '?', 'Can', 'you', 'explain', 'to', 'me', 'what', 'is', 'CKD', 'Is', 'CKD', 'a', 'sudden', 'disease', 'like', 'heart', 'attack', '?', 'How', 'does', 'CKD', 'affect', 'the', 'kidneys', '?', 'What', 'are', 'the', 'causes', 'of', 'CKD', '?', 'Is', 'diabetes', 'one', 'of', 'the', 'causes', 'of', 'CKD', '?', 'Is', 'high', 'blood', 'pressure', 'one', 'of', 'the', 'causes', 'of', 'CKD', '?', 'Are', 'there', 'any', 'symptops', 'of', 'CKD', '?', 'What', 'are', 'the', 'symptoms', 'of', 'CKD', '?', 'Are', 'there', 'any', 'complications', 'associated', 'with', 'CKD', '?', 'What', 'is', 'the', 'worst', 'symptom', 'of', 'CKD', '?', 'How', 'does', 'CKD', 'affect', 'the', 'body', '?', 'Is', 'one', 'of', 'the', 'symptops', 'of', 'CKD', 'fatigue', '?', 'Is', 'one', 'of', 'the', 'symptops', 'of', 'CKD', 'swelling', '?', 'Is', 'one', 'of', 'the', 'symptops', 'of', 'CKD', 'changes', 'in', 'urine', 'output', '?', 'Is', 'one', 'of', 'the', 'symptops', 'of', 'CKD', 'anemia', '?', 'Is', 'one', 'of', 'the', 'symptops', 'of', 'CKD', 'bone', 'disease', '?', 'Is', 'one', 'of', 'the', 'symptops', 'of', 'CKD', 'high', 'blood', 'pressure', '?', 'Is', 'one', 'of', 'the', 'symptops', 'of', 'CKD', 'infections', '?', 'Is', 'one', 'of', 'the', 'symptops', 'of', 'CKD', 'nerve', 'damage', '?', 'Is', 'one', 'of', 'the', 'symptops', 'of', 'CKD', 'poor', 'nutrition', '?', 'Can', 'you', 'provide', 'me', 'a', 'list', 'of', 'symptoms', 'for', 'CKD', '?', 'Can', 'CKD', 'cause', 'kidney', 'failure', '?', 'How', 'is', 'CKD', 'diagnosed', '?', 'Can', 'you', 'diagnose', 'CKD', '?', 'How', 'does', 'the', 'app', 'and', 'hardware', 'help', 'diagnose', 'CKD', '?', 'How', 'is', 'CKD', 'treated', '?', 'How', 'is', 'CKD', 'treated', 'in', 'children', '?', 'What', 'is', 'the', 'treatment', 'for', 'advanced', 'CKD', '?', 'Can', 'CKD', 'be', 'managed', 'with', 'diet', 'and', 'exercise', 'alone', '?', 'How', 'is', 'CKD', 'treated', 'in', 'the', 'early', 'stages', '?', 'What', 'are', 'the', 'possible', 'treatments', 'for', 'advanced', 'CKD', '?', 'Can', 'CKD', 'be', 'treated', '?', 'Can', 'CKD', 'be', 'treated', 'with', 'medications', '?', 'Can', 'CKD', 'be', 'treated', 'with', 'a', 'kidney', 'transplant', '?', 'Can', 'CKD', 'be', 'treated', 'with', 'dialysis', '?', 'Can', 'CKD', 'be', 'treated', 'with', 'exercise', '?', 'Can', 'CKD', 'be', 'prevented', '?', 'Can', 'CKD', 'be', 'prevented', 'in', 'people', 'with', 'high', 'blood', 'pressure', '?', 'Can', 'CKD', 'be', 'prevented', 'in', 'people', 'with', 'diabetes', '?', 'Does', 'having', 'a', 'healthy', 'lifestyle', 'prevent', 'CKD', '?', 'What', 'are', 'possible', 'ways', 'one', 'can', 'do', 'to', 'prevent', 'CKD', '?', 'How', 'can', 'I', 'prevent', 'myself', 'from', 'developing', 'CKD', '?', 'Can', 'CKD', 'be', 'prevented', 'in', 'people', 'with', 'a', 'family', 'history', 'of', 'the', 'disease', '?', 'Is', 'there', 'anything', 'that', 'can', 'be', 'done', 'to', 'prevent', 'people', 'that', 'have', 'a', 'family', 'history', 'of', 'CKD', 'My', 'family', 'has', 'a', 'history', 'of', 'CKD', '.', 'Is', 'there', 'anything', 'I', 'can', 'do', 'to', 'lower', 'the', 'chance', 'of', 'me', 'developing', 'CKD', '?', 'Is', 'there', 'an', 'increased', 'risk', 'of', 'me', 'getting', 'CKD', 'since', 'I', 'have', 'a', 'family', 'history', 'of', 'CKD', '?', 'Are', 'the', 'chances', 'of', 'people', 'developing', 'CKD', 'higher', 'after', 'they', 'have', 'a', 'family', 'history', 'of', 'CKD', '?', 'Is', 'there', 'a', 'cure', 'for', 'CKD', '?', 'W ...

# %%
ignore_words = ['?', '!', '.', ',']
all_words = [stem(w) for w in all_words if w not in ignore_words]
print(all_words)
# Out:
# ['hi', 'hey', 'how', 'are', 'you', 'hi', 'chatbot', 'hello', 'good', 'morn', 'good', 'afternoon', 'good', 'even', 'howdi', 'chatbot', 'are', 'you', 'the', 'question', 'and', 'answer', 'chatbot', 'i', 'am', 'look', 'for', 'bye', 'see', 'you', 'later', 'goodby', 'see', 'you', 'next', 'time', 'i', 'will', 'be', 'back', 'later', 'hope', 'to', 'see', 'you', 'again', 'good', 'night', 'what', 'is', 'chronic', 'kidney', 'diseas', 'is', 'chronic', 'kidney', 'diseas', 'the', 'same', 'as', 'ckd', 'can', 'you', 'explain', 'to', 'me', 'what', 'is', 'ckd', 'is', 'ckd', 'a', 'sudden', 'diseas', 'like', 'heart', 'attack', 'how', 'doe', 'ckd', 'affect', 'the', 'kidney', 'what', 'are', 'the', 'caus', 'of', 'ckd', 'is', 'diabet', 'one', 'of', 'the', 'caus', 'of', 'ckd', 'is', 'high', 'blood', 'pressur', 'one', 'of', 'the', 'caus', 'of', 'ckd', 'are', 'there', 'ani', 'symptop', 'of', 'ckd', 'what', 'are', 'the', 'symptom', 'of', 'ckd', 'are', 'there', 'ani', 'complic', 'associ', 'with', 'ckd', 'what', 'is', 'the', 'worst', 'symptom', 'of', 'ckd', 'how', 'doe', 'ckd', 'affect', 'the', 'bodi', 'is', 'one', 'of', 'the', 'symptop', 'of', 'ckd', 'fatigu', 'is', 'one', 'of', 'the', 'symptop', 'of', 'ckd', 'swell', 'is', 'one', 'of', 'the', 'symptop', 'of', 'ckd', 'chang', 'in', 'urin', 'output', 'is', 'one', 'of', 'the', 'symptop', 'of', 'ckd', 'anemia', 'is', 'one', 'of', 'the', 'symptop', 'of', 'ckd', 'bone', 'diseas', 'is', 'one', 'of', 'the', 'symptop', 'of', 'ckd', 'high', 'blood', 'pressur', 'is', 'one', 'of', 'the', 'symptop', 'of', 'ckd', 'infect', 'is', 'one', 'of', 'the', 'symptop', 'of', 'ckd', 'nerv', 'damag', 'is', 'one', 'of', 'the', 'symptop', 'of', 'ckd', 'poor', 'nutrit', 'can', 'you', 'provid', 'me', 'a', 'list', 'of', 'symptom', 'for', 'ckd', 'can', 'ckd', 'caus', 'kidney', 'failur', 'how', 'is', 'ckd', 'diagnos', 'can', 'you', 'diagnos', 'ckd', 'how', 'doe', 'the', 'app', 'and', 'hardwar', 'help', 'diagnos', 'ckd', 'how', 'is', 'ckd', 'treat', 'how', 'is', 'ckd', 'treat', 'in', 'children', 'what', 'is', 'the', 'treatment', 'for', 'advanc', 'ckd', 'can', 'ckd', 'be', 'manag', 'with', 'diet', 'and', 'exercis', 'alon', 'how', 'is', 'ckd', 'treat', 'in', 'the', 'earli', 'stage', 'what', 'are', 'the', 'possibl', 'treatment', 'for', 'advanc', 'ckd', 'can', 'ckd', 'be', 'treat', 'can', 'ckd', 'be', 'treat', 'with', 'medic', 'can', 'ckd', 'be', 'treat', 'with', 'a', 'kidney', 'transplant', 'can', 'ckd', 'be', 'treat', 'with', 'dialysi', 'can', 'ckd', 'be', 'treat', 'with', 'exercis', 'can', 'ckd', 'be', 'prevent', 'can', 'ckd', 'be', 'prevent', 'in', 'peopl', 'with', 'high', 'blood', 'pressur', 'can', 'ckd', 'be', 'prevent', 'in', 'peopl', 'with', 'diabet', 'doe', 'have', 'a', 'healthi', 'lifestyl', 'prevent', 'ckd', 'what', 'are', 'possibl', 'way', 'one', 'can', 'do', 'to', 'prevent', 'ckd', 'how', 'can', 'i', 'prevent', 'myself', 'from', 'develop', 'ckd', 'can', 'ckd', 'be', 'prevent', 'in', 'peopl', 'with', 'a', 'famili', 'histori', 'of', 'the', 'diseas', 'is', 'there', 'anyth', 'that', 'can', 'be', 'done', 'to', 'prevent', 'peopl', 'that', 'have', 'a', 'famili', 'histori', 'of', 'ckd', 'my', 'famili', 'ha', 'a', 'histori', 'of', 'ckd', 'is', 'there', 'anyth', 'i', 'can', 'do', 'to', 'lower', 'the', 'chanc', 'of', 'me', 'develop', 'ckd', 'is', 'there', 'an', 'increas', 'risk', 'of', 'me', 'get', 'ckd', 'sinc', 'i', 'have', 'a', 'famili', 'histori', 'of', 'ckd', 'are', 'the', 'chanc', 'of', 'peopl', 'develop', 'ckd', 'higher', 'after', 'they', 'have', 'a', 'famili', 'histori', 'of', 'ckd', 'is', 'there', 'a', 'cure', 'for', 'ckd', 'what', 'are', 'the', 'possibl', 'cure', 'for', 'ckd', 'is', 'the', 'cure', 'for', 'ckd', 'alreadi', 'avail', 'how', 'mani', 'peopl', 'have', 'alreadi', 'been', 'cure', 'of', 'ckd', 'what', 'is', 'the', 'outlook', 'for', 'someon', 'with', 'ckd', 'how', 'doe', 'ckd', 'affect', 'someon', 'with', 'ckd', "'s", 'outlook', 'are', 'there', 'ani', 'lifestyl', 'chang', 'that', 'can', 'help', 'manag', 'ckd', 'what', 'are' ...

# %%
all_words = sorted(set(all_words))
tags = sorted(set(tags))
print(tags)
# Out:
# ['about', 'anemia_fatigue_treatment', 'antibotics_treatment', 'causes', 'cure', 'diabetes_CKD', 'diabetes_treatment', 'diagnosis', 'donation', 'experimental_treatments', 'farewell', 'gender_common', 'greeting', 'high_blood_pressure_treatment', 'high_calcium_bone_diease_treatment', 'high_cholesterol_level', 'inheritance', 'lifestyle', 'monitoring', 'nerve_damage_treament', 'outlook', 'poor_nutrition_treatment', 'possibly_unsafe_treatments', 'prevention', 'prevention_family_history', 'race_common', 'reverse', 'skin_problems_treatment', 'special_diet', 'swelling_urine_output_treatment', 'symptoms', 'treatment']

# %%
xy
# Out:
# [(['Hi'], 'greeting'),
#  (['Hey'], 'greeting'),
#  (['How', 'are', 'you', '?'], 'greeting'),
#  (['Hi', 'Chatbot'], 'greeting'),
#  (['Hello'], 'greeting'),
#  (['Good', 'morning'], 'greeting'),
#  (['Good', 'afternoon'], 'greeting'),
#  (['Good', 'evening'], 'greeting'),
#  (['Howdy', 'chatbot'], 'greeting'),
#  (['Are',
#    'you',
#    'the',
#    'Question',
#    'and',
#    'Answer',
#    'chatbot',
#    'I',
#    'am',
#    'looking',
#    'for',
#    '?'],
#   'greeting'),
#  (['Bye'], 'farewell'),
#  (['See', 'you', 'later'], 'farewell'),
#  (['Goodbye'], 'farewell'),
#  (['See', 'you', 'next', 'time'], 'farewell'),
#  (['I', 'will', 'be', 'back', 'later'], 'farewell'),
#  (['Hope', 'to', 'see', 'you', 'again'], 'farewell'),
#  (['Good', 'night'], 'farewell'),
#  (['What', 'is', 'Chronic', 'Kidney', 'Disease', '?'], 'about'),
#  (['Is', 'Chronic', 'Kidney', 'Disease', 'the', 'same', 'as', 'CKD', '?'],
#   'about'),
#  (['Can', 'you', 'explain', 'to', 'me', 'what', 'is', 'CKD'], 'about'),
#  (['Is', 'CKD', 'a', 'sudden', 'disease', 'like', 'heart', 'attack', '?'],
#   'about'),
#  (['How', 'does', 'CKD', 'affect', 'the', 'kidneys', '?'], 'about'),
#  (['What', 'are', 'the', 'causes', 'of', 'CKD', '?'], 'causes'),
#  (['Is', 'diabetes', 'one', 'of', 'the', 'causes', 'of', 'CKD', '?'],
#   'causes'),
#  (['Is',
#    'high',
#    'blood',
#    'pressure',
#    'one',
#    'of',
#    'the',
#    'causes',
#    'of',
#    'CKD',
#    '?'],
#   'causes'),
#  (['Are', 'there', 'any', 'symptops', 'of', 'CKD', '?'], 'symptoms'),
#  (['What', 'are', 'the', 'symptoms', 'of', 'CKD', '?'], 'symptoms'),
#  (['Are', 'there', 'any', 'complications', 'associated', 'with', 'CKD', '?'],
#   'symptoms'),
#  (['What', 'is', 'the', 'worst', 'symptom', 'of', 'CKD', '?'], 'symptoms'),
#  (['How', 'does', 'CKD', 'affect', 'the', 'body', '?'], 'symptoms'),
#  (['Is', 'one', 'of', 'the', 'symptops', 'of', 'CKD', 'fatigue', '?'],
#   'symptoms'),
#  (['Is', 'one', 'of', 'the', 'symptops', 'of', 'CKD', 'swelling', '?'],
#   'symptoms'),
#  (['Is',
#    'one',
#    'of',
#    'the',
#    'symptops',
#    'of',
#    'CKD',
#    'changes',
#    'in',
#    'urine',
#    'output',
#    '?'],
#   'symptoms'),
#  (['Is', 'one', 'of', 'the', 'symptops', 'of', 'CKD', 'anemia', '?'],
#   'symptoms'),
#  (['Is', 'one', 'of', 'the', 'symptops', 'of', 'CKD', 'bone', 'disease', '?'],
#   'symptoms'),
#  (['Is',
#    'one',
#    'of',
#    'the',
#    'symptops',
#    'of',
#    'CKD',
#    'high',
#    'blood',
#    'pressure',
#    '?'],
#   'symptoms'),
#  (['Is', 'one', 'of', 'the', 'symptops', 'of', 'CKD', 'infections', '?'],
#   'symptoms'),
#  (['Is', 'one', 'of', 'the', 'symptops', 'of', 'CKD', 'nerve', 'damage', '?'],
#   'symptoms'),
#  (['Is',
#    'one',
#    'of',
#    'the',
#    'symptops',
#    'of',
#    'CKD',
#    'poor',
#    'nutrition',
#    '?'],
#   'symptoms'),
#  (['Can',
#    'you',
#    'provide',
#    'me',
#    'a',
#    'list',
#    'of',
#    'symptoms',
#    'for',
#    'CKD',
#    '?'],
#   'symptoms'),
#  (['Can', 'CKD', 'cause', 'kidney', 'failure', '?'], 'symptoms'),
#  (['How', 'is', 'CKD', 'diagnosed', '?'], 'diagnosis'),
#  (['Can', 'you', 'diagnose', 'CKD', '?'], 'diagnosis'),
#  (['How',
#    'does',
#    'the',
#    'app',
#    'and',
#    'hardware',
#    'help',
#    'diagnose',
#    'CKD',
#    '?'],
#   'diagnosis'),
#  (['How', 'is', 'CKD', 'treated', '?'], 'treatment'),
#  (['How', 'is', 'CKD', 'treated', 'in', 'children', '?'], 'treatment'),
#  (['What', 'is', 'the', 'treatment', 'for', 'advanced', 'CKD', '?'],
#   'treatment'),
#  (['Can',
#    'CKD',
#    'be',
#    'managed',
#    'with',
#    'diet',
#    'and',
#    'exercise',
#    'alone',
#    '?'],
#   'treatment'),
#  (['How', 'is', 'CKD', 'treated', 'in', 'the', 'early', 'stages', '?'],
#   'treatment'),
#  (['What',
#    'are',
#    'the',
#    'possible',
#    'treatments',
#    'for',
#    'advanced',
#    'CKD',
#    '?'],
#   'treatment'),
#  (['Can', 'CKD', 'be', 'treated', '?'], 'treatment'),
#  (['Can', 'CKD', 'be', 'treated', 'with', 'medications', '?'], 'treatment'),
#  (['Can', 'CKD', 'be', 'treated', 'with', 'a', 'kidney', 'transplant', '?'],
#   'treatment'),
#  (['Can', 'CKD', 'be', 'treated', 'with', 'dialysis', '?'], 'treatment'),
#  (['Can', 'CKD', 'be', 'treated', 'with', 'exercise', '?'], 'treatment'),
#  (['Can', 'CKD', 'be', 'prevented', '?'], 'prevention'),
#  (['Can',
#    'CKD',
#    'be',
#    'prevented',
#    'in',
#    'people',
#    'with',
#    'high',
#    'blood',
#    'pressure',
#    '?'],
#   'prevention'),
#  (['Can', 'CKD', 'be', 'prevented', 'in', 'people', 'with', 'diabetes', '?'],
#   'prevention'),
#  (['Does', 'having', 'a', 'healthy', 'lifestyle', 'prevent', 'CKD', '?'],
#   'prevention'),
#  (['What',
#    'are',
#    'possible',
#    'ways',
#    'one',
#    'can',
#    'do',
#    'to',
#    'prevent',
#    'CKD',
#    '?'],
#   'prevention'),
#  (['How', 'can', 'I', 'prevent', 'myself', 'from', 'developing', 'CKD', '?'],
#   'prevention'),
#  (['Can',
#    'CKD',
#    'be',
#    'prevented',
#    'in',
#    'people',
#    'with',
#    'a',
#    'family',
#    'history',
#    'of',
#    'the',
#    'disease',
#    '?'],
#   'prevention_family_history'),
#  (['Is',
#    'there',
#    'anything',
#    'that',
#    'can',
#    'be',
#    'done',
#    'to',
#    'prevent',
#    'people',
#    'that',
#    'have',
#    'a',
#    'family',
#    'history',
#    'of',
#    'CKD'],
#   'prevention_family_history'),
#  (['My',
#    'family',
#    'has',
#    'a',
#    'history',
#    'of',
#    'CKD',
#    '.',
#    'Is',
#    'there',
#    'anything',
#    'I',
#    'can',
#    'do',
#    'to',
#    'lower',
#    'the',
#    'chance',
#    'of',
#    'me',
#    'developing',
#    'CKD',
#    '?'],
#   'prevention_family_history'),
#  (['Is',
#    'there',
#    'an',
#    'increased',
#    'risk',
#    'of',
#    'me',
#    'getting',
#    'CKD',
#    'since',
#    'I',
#    'have',
#    'a',
#    'family',
#    'history',
#    'of',
#    'CKD',
#    '?'],
#   'prevention_family_history'),
#  (['Are',
#    'the',
#    'chances',
#    'of',
#    'people',
#    'developing',
#    'CKD',
#    'higher',
#    'after',
#    'they',
#    'have',
#    'a',
#    'family',
#    'history',
#    'of',
#    'CKD',
#    '?'],
#   'prevention_family_history'),
#  (['Is', 'there', 'a', 'cure', 'for', 'CKD', '?'], 'cure'),
#  (['What', 'are', 'the', 'possible', 'cure', 'for', 'CKD', '?'], 'cure'),
#  (['Is', 'the', 'cure', 'for', 'CKD', 'already', 'available', '?'], 'cure'),
#  (['How',
#    'many',
#    'people',
#    'have',
#    'already',
#    'been',
#    'cured',
#    'of',
#    'CKD',
#    '?'],
#   'cure'),
#  (['What', 'is', 'the', 'outlook', 'for', 'someone', 'with', 'CKD', '?'],
#   'outlook'),
#  (['How',
#    'does',
#    'CKD',
#    'affect',
#    'someone',
#    'with',
#    'CKD',
#    "'s",
#    'outlook',
#    '?'],
#   'outlook'),
#  (['Are',
#    'there',
#    'any',
#    'lifestyle',
#    'changes',
#    'that',
#    'can',
#    'help',
#    'manage',
#    'CKD',
#    '?'],
#   'lifestyle'),
#  (['What',
#    'are',
#    'possible',
#    'lifestyle',
#    'changes',
#    'that',
#    'can',
#    'help',
#    'manage',
#    'CKD',
#    '?'],
#   'lifestyle'),
#  (['What',
#    'are',
#    'the',
#    'various',
#    'lifestyle',
#    'changes',
#    'one',
#    'can',
#    'make',
#    'to',
#    'manage',
#    'CKD',
#    '?'],
#   'lifestyle'),
#  (['Can', 'CKD', 'be', 'reversed', '?'], 'reverse'),
#  (['Can', 'CKD', 'be', 'reversed', 'in', 'the', 'early', 'stages', '?'],
#   'reverse'),
#  (['Is',
#    'it',
#    'possible',
#    'to',
#    'revert',
#    'my',
#    'health',
#    'back',
#    'to',
#    'when',
#    'I',
#    'have',
#    'no',
#    'CKD',
#    '?'],
#   'reverse'),
#  (['Can',
#    'someone',
#    'revert',
#    'their',
#    'health',
#    'back',
#    'to',
#    'when',
#    'they',
#    'have',
#    'no',
#    'CKD',
#    '?'],
#   'reverse'),
#  (['Is',
#    'it',
#    'possible',
#    'to',
#    'no',
#    'longer',
#    'have',
#    'CKD',
#    'after',
#    'being',
#    'diagnosed',
#    '?'],
#   'reverse'),
#  (['How', 'is', 'CKD', 'monitored', '?'], 'monitoring'),
#  (['How', 'is', 'the', 'monitoring', 'of', 'CKD', 'performed', '?'],
#   'monitoring'),
#  (['How', 'can', 'the', 'app', 'and', 'hardware', 'monitor', 'CKD', '?'],
#   'monitoring'),
#  (['What',
#    'is',
#    'the',
#    'relationship',
#    'between',
#    'CKD',
#    'and',
#    'diabetes',
#    '?'],
#   'diabetes_CKD'),
#  (['Is',
#    'there',
#    'any',
#    'relationship',
#    'between',
#    'CKD',
#    'and',
#    'diabetes',
#    '?'],
#   'diabetes_CKD'),
#  (['Does', 'having', 'diabetes', 'contribute', 'to', 'having', 'CKD', '?'],
#   'diabetes_CKD'),
#  (['Is',
#    'diabetes',
#    'a',
#    'contributing',
#    'factor',
#    'of',
#    'developing',
#    'CKD',
#    '?'],
#   'diabetes_CKD'),
#  (['Does', 'having', 'diabetes', 'means', 'I', 'will', 'develop', 'CKD', '?'],
#   'diabetes_CKD'),
#  (['Is',
#    'it',
#    'possible',
#    'to',
#    'donate',
#    'a',
#    'kidney',
#    'while',
#    'living',
#    'with',
#    'CKD',
#    '?'],
#   'donation'),
#  (['Can', 'I', 'donate', 'a', 'kidney', 'while', 'I', 'have', 'CKD', '?'],
#   'donation'),
#  (['While',
#    'having',
#    'CKD',
#    ',',
#    'can',
#    'someone',
#    'donate',
#    'a',
#    'kidney',
#    '?'],
#   'donation'),
#  (['Can', 'CKD', 'be', 'inherited', '?'], 'inheritance'),
#  (['Is', 'CKD', 'a', 'hereditary', 'disease', '?'], 'inheritance'),
#  (['Is',
#    'it',
#    'possible',
#    'that',
#    'my',
#    'kids',
#    'will',
#    'have',
#    'CKD',
#    'if',
#    'I',
#    'am',
#    'currently',
#    'living',
#    'with',
#    'CKD',
#    '?'],
#   'inheritance'),
#  (['What', 'are', 'the', 'genetic', 'conditions', 'that', 'cause', 'CKD', '?'],
#   'inheritance'),
#  (['Can', 'CKD', 'be', 'treated', 'with', 'natural', 'remedies', '?'],
#   'possibly_unsafe_treatments'),
#  (['Can', 'CKD', 'be', 'treated', 'with', 'herbal', 'supplements', '?'],
#   'possibly_unsafe_treatments'),
#  (['Can', 'CKD', 'be', 'treated', 'with', 'acupuncture', '?'],
#   'possibly_unsafe_treatments'),
#  (['Can', 'CKD', 'be', 'treated', 'with', 'supplements', '?'],
#   'possibly_unsafe_treatments'),
#  (['Can', 'CKD', 'be', 'treated', 'with', 'home', 'remedies', '?'],
#   'possibly_unsafe_treatments'),
#  (['Is',
#    'natural',
#    'remedies',
#    'one',
#    'of',
#    'the',
#    'treatments',
#    'of',
#    'CKD',
#    '?'],
#   'possibly_unsafe_treatments'),
#  (['Is',
#    'herbal',
#    'supplements',
#    'one',
#    'of',
#    'the',
#    'treatments',
#    'of',
#    'CKD',
#    '?'],
#   'possibly_unsafe_treatments'),
#  (['Is', 'acupuncture', 'one', 'of', 'the', 'treatments', 'of', 'CKD', '?'],
#   'possibly_unsafe_treatments'),
#  (['Is',
#    'supplements',
#    'remedies',
#    'one',
#    'of',
#    'the',
#    'treatments',
#    'of',
#    'CKD',
#    '?'],
#   'possibly_unsafe_treatments'),
#  (['Is',
#    'home',
#    'remedies',
#    'remedies',
#    'one',
#    'of',
#    'the',
#    'treatments',
#    'of',
#    'CKD',
#    '?'],
#   'possibly_unsafe_treatments'),
#  (['Can', 'I', 'use', 'natural', 'remedies', 'to', 'treat', 'CKD', '?'],
#   'possibly_unsafe_treatments'),
#  (['Can', 'I', 'use', 'herbal', 'supplements', 'to', 'treat', 'CKD', '?'],
#   'possibly_unsafe_treatments'),
#  (['Can', 'I', 'use', 'acupuncture', 'to', 'treat', 'CKD', '?'],
#   'possibly_unsafe_treatments'),
#  (['Can', 'I', 'use', 'supplements', 'to', 'treat', 'CKD', '?'],
#   'possibly_unsafe_treatments'),
#  (['Can', 'I', 'use', 'home', 'remedies', 'to', 'treat', 'CKD', '?'],
#   'possibly_unsafe_treatments'),
#  (['Can', 'CKD', 'be', 'treated', 'with', 'antibiotics', '?'],
#   'antibotics_treatment'),
#  (['Can',
#    'CKD',
#    'be',
#    'treated',
#    'with',
#    'medications',
#    'for',
#    'infections',
#    '?'],
#   'antibotics_treatment'),
#  (['Can', 'I', 'use', 'antibiotics', 'to', 'treat', 'infections', '?'],
#   'antibotics_treatment'),
#  (['Can', 'I', 'use', 'medications', 'to', 'treat', 'infections', '?'],
#   'antibotics_treatment'),
#  (['Can',
#    'CKD',
#    'be',
#    'treated',
#    'with',
#    'medications',
#    'for',
#    'high',
#    'blood',
#    'pressure',
#    '?'],
#   'high_blood_pressure_treatment'),
#  (['Can',
#    'I',
#    'use',
#    'medications',
#    'to',
#    'treat',
#    'high',
#    'blood',
#    'pressure',
#    'in',
#    'people',
#    'with',
#    'CKD',
#    '?'],
#   'high_blood_pressure_treatment'),
#  (['Which',
#    'medications',
#    'can',
#    'I',
#    'use',
#    'to',
#    'lower',
#    'blood',
#    'pressure',
#    '?'],
#   'high_blood_pressure_treatment'),
#  (['Can',
#    'CKD',
#    'be',
#    'treated',
#    'with',
#    'medications',
#    'for',
#    'diabetes',
#    '?'],
#   'diabetes_treatment'),
#  (['Can',
#    'I',
#    'use',
#    'medications',
#    'to',
#    'treat',
#    'diabetes',
#    'in',
#    'people',
#    'with',
#    'CKD',
#    '?'],
#   'diabetes_treatment'),
#  (['Which',
#    'medications',
#    'can',
#    'I',
#    'use',
#    'to',
#    'lower',
#    'blood',
#    'sugar',
#    'levels',
#    '?'],
#   'diabetes_treatment'),
#  (['Can',
#    'CKD',
#    'be',
#    'treated',
#    'with',
#    'medications',
#    'for',
#    'bone',
#    'disease',
#    '?'],
#   'high_calcium_bone_diease_treatment'),
#  (['Can',
#    'CKD',
#    'be',
#    'treated',
#    'with',
#    'medications',
#    'for',
#    'high',
#    'calcium',
#    'levels',
#    '?'],
#   'high_calcium_bone_diease_treatment'),
#  (['Can',
#    'I',
#    'use',
#    'medications',
#    'to',
#    'treat',
#    'bone',
#    'disease',
#    'in',
#    'people',
#    'with',
#    'CKD',
#    '?'],
#   'high_calcium_bone_diease_treatment'),
#  (['Which',
#    'medications',
#    'can',
#    'I',
#    'use',
#    'treat',
#    'bone',
#    'disease',
#    'in',
#    'people',
#    'with',
#    'CKD',
#    '?'],
#   'high_calcium_bone_diease_treatment'),
#  (['Can',
#    'I',
#    'use',
#    'medications',
#    'to',
#    'treat',
#    'high',
#    'calcium',
#    'levels',
#    'in',
#    'people',
#    'with',
#    'CKD',
#    '?'],
#   'high_calcium_bone_diease_treatment'),
#  (['Which',
#    'medications',
#    'can',
#    'I',
#    'use',
#    'to',
#    'lower',
#    'calcium',
#    'level',
#    'in',
#    'people',
#    'with',
#    'CKD',
#    '?'],
#   'high_calcium_bone_diease_treatment'),
#  (['Can', 'CKD', 'be', 'treated', 'with', 'medications', 'for', 'anemia', '?'],
#   'anemia_fatigue_treatment'),
#  (['Can',
#    'CKD',
#    'be',
#    'treated',
#    'with',
#    'medications',
#    'for',
#    'fatigue',
#    '?'],
#   'anemia_fatigue_treatment'),
#  (['Can',
#    'I',
#    'use',
#    'medications',
#    'to',
#    'treat',
#    'anemia',
#    'in',
#    'people',
#    'with',
#    'CKD',
#    '?'],
#   'anemia_fatigue_treatment'),
#  (['Which',
#    'medications',
#    'can',
#    'I',
#    'use',
#    'treat',
#    'anemia',
#    'in',
#    'people',
#    'with',
#    'CKD',
#    '?'],
#   'anemia_fatigue_treatment'),
#  (['Can',
#    'I',
#    'use',
#    'medications',
#    'to',
#    'treat',
#    'fatigue',
#    'in',
#    'people',
#    'with',
#    'CKD',
#    '?'],
#   'anemia_fatigue_treatment'),
#  (['Which',
#    'medications',
#    'can',
#    'I',
#    'use',
#    'to',
#    'reduce',
#    'fatigue',
#    'in',
#    'people',
#    'with',
#    'CKD',
#    '?'],
#   'anemia_fatigue_treatment'),
#  (['Can',
#    'CKD',
#    'be',
#    'treated',
#    'with',
#    'medications',
#    'for',
#    'nerve',
#    'damage',
#    '?'],
#   'nerve_damage_treament'),
#  (['Can',
#    'I',
#    'use',
#    'medications',
#    'to',
#    'treat',
#    'nerve',
#    'damage',
#    'in',
#    'people',
#    'with',
#    'CKD',
#    '?'],
#   'nerve_damage_treament'),
#  (['Which',
#    'medications',
#    'can',
#    'I',
#    'use',
#    'to',
#    'reduce',
#    'nerve',
#    'damage',
#    'in',
#    'people',
#    'with',
#    'CKD',
#    '?'],
#   'nerve_damage_treament'),
#  (['Can',
#    'CKD',
#    'be',
#    'treated',
#    'with',
#    'medications',
#    'for',
#    'poor',
#    'nutrition',
#    '?'],
#   'poor_nutrition_treatment'),
#  (['Can',
#    'I',
#    'use',
#    'medications',
#    'to',
#    'treat',
#    'poor',
#    'nutrition',
#    'in',
#    'people',
#    'with',
#    'CKD',
#    '?'],
#   'poor_nutrition_treatment'),
#  (['Which',
#    'medications',
#    'can',
#    'I',
#    'use',
#    'to',
#    'treat',
#    'poor',
#    'nutrition',
#    'in',
#    'people',
#    'with',
#    'CKD',
#    '?'],
#   'poor_nutrition_treatment'),
#  (['Can',
#    'CKD',
#    'be',
#    'treated',
#    'with',
#    'medications',
#    'for',
#    'swelling',
#    '?'],
#   'swelling_urine_output_treatment'),
#  (['Can',
#    'CKD',
#    'be',
#    'treated',
#    'with',
#    'medications',
#    'for',
#    'changes',
#    'in',
#    'urine',
#    'output',
#    '?'],
#   'swelling_urine_output_treatment'),
#  (['Can',
#    'I',
#    'use',
#    'medications',
#    'to',
#    'treat',
#    'swelling',
#    'in',
#    'people',
#    'with',
#    'CKD',
#    '?'],
#   'swelling_urine_output_treatment'),
#  (['Which',
#    'medications',
#    'can',
#    'I',
#    'use',
#    'to',
#    'reduce',
#    'swelling',
#    'in',
#    'people',
#    'with',
#    'CKD',
#    '?'],
#   'swelling_urine_output_treatment'),
#  (['Can',
#    'I',
#    'use',
#    'medications',
#    'to',
#    'treat',
#    'urine',
#    'output',
#    'changes',
#    'in',
#    'people',
#    'with',
#    'CKD',
#    '?'],
#   'swelling_urine_output_treatment'),
#  (['Which',
#    'medications',
#    'can',
#    'I',
#    'use',
#    'to',
#    'make',
#    'urine',
#    'output',
#    'changes',
#    'go',
#    'back',
#    'to',
#    'normal',
#    'in',
#    'people',
#    'with',
#    'CKD',
#    '?'],
#   'swelling_urine_output_treatment'),
#  (['Can',
#    'CKD',
#    'be',
#    'treated',
#    'with',
#    'medications',
#    'for',
#    'skin',
#    'problems',
#    '?'],
#   'skin_problems_treatment'),
#  (['Can',
#    'I',
#    'use',
#    'medications',
#    'to',
#    'treat',
#    'skin',
#    'problems',
#    'in',
#    'people',
#    'with',
#    'CKD',
#    '?'],
#   'skin_problems_treatment'),
#  (['Which',
#    'medications',
#    'can',
#    'I',
#    'use',
#    'to',
#    'treat',
#    'skin',
#    'problems',
#    'in',
#    'people',
#    'with',
#    'CKD',
#    '?'],
#   'skin_problems_treatment'),
#  (['Can',
#    'CKD',
#    'be',
#    'treated',
#    'with',
#    'medications',
#    'for',
#    'high',
#    'cholesterol',
#    '?'],
#   'high_cholesterol_level'),
#  (['Can',
#    'I',
#    'use',
#    'medications',
#    'to',
#    'treat',
#    'high',
#    'cholesterol',
#    'in',
#    'people',
#    'with',
#    'CKD',
#    '?'],
#   'high_cholesterol_level'),
#  (['Which',
#    'medications',
#    'can',
#    'I',
#    'use',
#    'to',
#    'lower',
#    'cholesterol',
#    'level',
#    'in',
#    'people',
#    'with',
#    'CKD',
#    '?'],
#   'high_cholesterol_level'),
#  (['Can', 'CKD', 'be', 'treated', 'with', 'stem', 'cell', 'therapy', '?'],
#   'experimental_treatments'),
#  (['Can', 'CKD', 'be', 'treated', 'with', 'gene', 'therapy', '?'],
#   'experimental_treatments'),
#  (['Can',
#    'I',
#    'use',
#    'medications',
#    'to',
#    'treat',
#    'fatigue',
#    'in',
#    'people',
#    'with',
#    'CKD',
#    '?'],
#   'experimental_treatments'),
#  (['Which',
#    'medications',
#    'can',
#    'I',
#    'use',
#    'to',
#    'reduce',
#    'fatigue',
#    'in',
#    'people',
#    'with',
#    'CKD',
#    '?'],
#   'experimental_treatments'),
#  (['Is', 'CKD', 'more', 'common', 'in', 'men', 'or', 'women', '?'],
#   'gender_common'),
#  (['For', 'which', 'gender', 'is', 'CKD', 'more', 'common', '?'],
#   'gender_common'),
#  (['Is', 'CKD', 'more', 'common', 'in', 'men', 'than', 'women', '?'],
#   'gender_common'),
#  (['Is', 'CKD', 'more', 'common', 'in', 'men', 'than', 'women', '?'],
#   'gender_common'),
#  (['Is',
#    'CKD',
#    'more',
#    'common',
#    'in',
#    'certain',
#    'racial',
#    'or',
#    'ethnic',
#    'groups',
#    '?'],
#   'race_common'),
#  (['For',
#    'which',
#    'race',
#    'or',
#    'ethnic',
#    'group',
#    'is',
#    'CKD',
#    'more',
#    'common',
#    '?'],
#   'race_common'),
#  (['Can', 'CKD', 'be', 'treated', 'with', 'a', 'special', 'diet', '?'],
#   'special_diet'),
#  (['Can', 'special', 'diet', 'be', 'used', 'to', 'treat', 'CKD', '?'],
#   'special_diet'),
#  (['Is',
#    'special',
#    'diet',
#    'something',
#    'that',
#    'can',
#    'be',
#    'used',
#    'to',
#    'treat',
#    'CKD',
#    '?'],
#   'special_diet')]

# %%
X_train = []
y_train = []
for (pattern_sentence, tag) in xy:
  bag = bag_of_words(pattern_sentence, all_words)
  X_train.append(bag)

  label = tags.index(tag)
  y_train.append(label) #used for CrossEntropyLoss later (not one-hot encoded)

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)
X_train.shape, y_train.shape
# Out:
# ((163, 199), (163,))

# %%
class ChatDataset(Dataset):
  def __init__(self):
    self.n_samples = len(X_train)
    self.x_data = X_train
    self.y_data = y_train
  
  def __getitem__(self, index):
    return self.x_data[index], self.y_data[index]
  
  def __len__(self):
    return self.n_samples

# %%
# Hyper-parameters 
num_epochs = 1000
batch_size = 8
learning_rate = 0.001
input_size = len(X_train[0])
hidden_size = 54
output_size = len(tags)
print(input_size, output_size)
# Out:
# 199 32

# %%
dataset = ChatDataset()
train_loader = DataLoader(dataset = dataset, batch_size = batch_size, shuffle = True, num_workers = 2)

# %%
class NeuralNet(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(NeuralNet, self).__init__()
        self.l1 = nn.Linear(input_size, hidden_size) 
        self.l2 = nn.Linear(hidden_size, hidden_size) 
        self.l3 = nn.Linear(hidden_size, num_classes)
        self.relu = nn.ReLU()
    
    def forward(self, x):
        out = self.l1(x)
        out = self.relu(out)
        out = self.l2(out)
        out = self.relu(out)
        out = self.l3(out)
        # no activation and no softmax at the end
        return out

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = NeuralNet(input_size, hidden_size, output_size).to(device)

# %%
# loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

# %%
# Train the model
for epoch in range(num_epochs):
    for (words, labels) in train_loader:
        words = words.to(device)
        labels = labels.to(dtype=torch.long).to(device)
        
        # Forward pass
        outputs = model(words)
        # if y would be one-hot, we must apply
        # labels = torch.max(labels, 1)[1]
        loss = criterion(outputs, labels)
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
    if (epoch+1) % 100 == 0:
        print (f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')


print(f'final loss: {loss.item():.4f}')
# Out:
# Epoch [100/1000], Loss: 0.0036
# Epoch [200/1000], Loss: 0.0018
# Epoch [300/1000], Loss: 0.0000
# Epoch [400/1000], Loss: 0.0001
# Epoch [500/1000], Loss: 0.0003
# Epoch [600/1000], Loss: 0.2353
# Epoch [700/1000], Loss: 0.2420
# Epoch [800/1000], Loss: 0.0000
# Epoch [900/1000], Loss: 0.0000
# Epoch [1000/1000], Loss: 0.0000
# final loss: 0.0000

# %%
data = {
    "model_state": model.state_dict(),
    "input_size": input_size,
    "output_size": output_size,
    "hidden_size": hidden_size,
    "all_words": all_words,
    "tags": tags
}

# %%
FILE = "data.pth"
torch.save(data, FILE)
print(f"training completed. file saved to {FILE}")
# Out:
# training completed. file saved to data.pth

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

with open("intents.json", 'r') as f:
  intents = json.load(f)

FILE = "data.pth"
data = torch.load(FILE)

input_size = data["input_size"]
hidden_size = data["hidden_size"]
output_size = data["output_size"]
all_words = data["all_words"]
tags = data["tags"]
model_state = data["model_state"]

model = NeuralNet(input_size, hidden_size, output_size).to(device)
model.load_state_dict(model_state)
model.eval()
# Out:
# NeuralNet(
#   (l1): Linear(in_features=199, out_features=54, bias=True)
#   (l2): Linear(in_features=54, out_features=54, bias=True)
#   (l3): Linear(in_features=54, out_features=32, bias=True)
#   (relu): ReLU()
# )

# %%
bot_name = "Sam"
print("Let's chat! Type 'q' to exit")
while True:
  sentence = input("You: ")
  if sentence == 'q':
    break
  
  sentence = tokenize(sentence)
  X = bag_of_words(sentence, all_words)
  X = X.reshape(1, X.shape[0])
  X = torch.from_numpy(X)

  output = model(X)
  _, predicted = torch.max(output, dim = 1)
  tag = tags[predicted.item()]

  probs = torch.softmax(output, dim = 1)
  prob = probs[0][predicted.item()]

  if prob.item() > 0.75:
    for intent in intents["intents"]:
      if tag == intent["tag"]:
        responses = intent["responses"]
        print(f"{bot_name}: {random.choice(responses)}")
  else:
    print(f"{bot_name}: I do not understand...")
# Out:
# Let's chat! Type 'q' to exit
# You: Hello
# Sam: Hello, I am here to answer to answer any questions you possibly have. Do not hesistate to ask me any as it is my duty to help you/
# You: May I know what is CKD?
# Sam: I do not understand...
# You: What is CKD?
# Sam: I do not understand...
# You: CKD
# Sam: I do not understand...
# You: Howdy
# Sam: Hi there, is there any question you have that I can answer?
# You: What are the symptoms of CKD?
# Sam: Symptoms of CKD may include swelling in the ankles and feet, fatigue, changes in urine output, anemia (low red blood cell count), bone disease, high blood pressure, infections, nerve damage and poor nutrition. Worst cases include kidney failure.
# You: Does medication cure swelling?
# Sam: Medications such as diuretics or ACE inhibitors may be used to treat swelling/urine output changes in people with CKD. However, these medications may not be suitable for everyone and may cause side effects.
# You: What is Chronic Kidney Disease?
# Sam: Chronic Kidney Disease also known as CKD is a condition in which the kidneys are damaged and are not able to filter waste and excess fluids from the body as effectively as they should. It is a progressive disease, which means that it gets worse over time.
# You: Is CKD harmful?
# Sam: In the early stages of CKD, treatment may focus on managing the underlying cause of the disease and slowing the progression of the kidney damage. In some cases, making lifestyle changes such as eating healthily and getting regular exercise can help manage CKD and slow the progression of the disease. However, in more advanced stages of CKD, medications and other treatments such as dialysis or a kidney transplant may also be necessary.
# You: How can one has CKD?
# Sam: I do not understand...
# You: What are the causes of CKD?
# Sam: There are several causes of CKD, including diabetes, high blood pressure, and certain infections.
# You: How does diabetes cause CKD?
# Sam: Diabetes is a common cause of CKD. High blood sugar levels associated with diabetes can damage the blood vessels in the kidneys, leading to kidney damage and impaired function. Managing diabetes can help prevent or slow the progression of CKD.
# You: What is Chronic Kidney Disease?
# Sam: Chronic Kidney Disease also known as CKD is a condition in which the kidneys are damaged and are not able to filter waste and excess fluids from the body as effectively as they should. It is a progressive disease, which means that it gets worse over time.
# You: Is diabetes related to Chronic Kidney Disease?
# Sam: Chronic Kidney Disease also known as CKD is a condition in which the kidneys are damaged and are not able to filter waste and excess fluids from the body as effectively as they should. It is a progressive disease, which means that it gets worse over time.
# You: Which race is CKD more common?
# Sam: I do not understand...
# You: What is the prevention for CKD?
# Sam: Maintaining a healthy blood pressure and good blood sugar control through lifestyle changes such as eating healthily, getting regular exercise, and taking medications as prescribed can help prevent or slow the progression of CKD.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-2969e5a6b264> in <module>
#       2 print("Let's chat! Type 'q' to exit")
#       3 while True:
# ----> 4   sentence = input("You: ")
#       5   if sentence == 'q':
#       6     break
#
# /usr/local/lib/python3.8/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# /usr/local/lib/python3.8/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
